# %% [markdown]
# <a href="https://colab.research.google.com/github/PrafullDixit12/Netflix_movies_Analysis/blob/main/Netflix_movies_Analysis.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# %%
df= pd.read_csv('/content/mymoviedb.csv', engine ='python' )
df.head(5)
# Out:
#   Release_Date                    Title  \
# 0   15-12-2021  Spider-Man: No Way Home
# 1   01-03-2022               The Batman
# 2   25-02-2022                  No Exit
# 3   24-11-2021                  Encanto
# 4   22-12-2021           The King's Man
#
#                                             Overview  Popularity Vote_Count  \
# 0  Peter Parker is unmasked and no longer able to...    5083.954       8940
# 1  In his second year of fighting crime, Batman u...    3827.658       1151
# 2  Stranded at a rest stop in the mountains durin...    2618.087        122
# 3  The tale of an extraordinary family, the Madri...    2402.201       5076
# 4  As a collection of history's worst tyrants and...    1895.511       1793
#
#   Vote_Average Original_Language                               Genre  \
# 0          8.3                en  Action, Adventure, Science Fiction
# 1          8.1                en            Crime, Mystery, Thriller
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 9837 entries, 0 to 9836
# Data columns (total 9 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   Release_Date       9837 non-null   object
#  1   Title              9828 non-null   object
#  2   Overview           9828 non-null   object
#  3   Popularity         9827 non-null   float64
#  4   Vote_Count         9827 non-null   object
#  5   Vote_Average       9827 non-null   object
#  6   Original_Language  9827 non-null   object
#  7   Genre              9826 non-null   object
#  8   Poster_Url         9826 non-null   object
# dtypes: float64(1), object(8)
# memory usage: 691.8+ KB

# %%
df['Genre'].head()
# Out:
# 0    Action, Adventure, Science Fiction
# 1              Crime, Mystery, Thriller
# 2                              Thriller
# 3    Animation, Comedy, Family, Fantasy
# 4      Action, Adventure, Thriller, War
# Name: Genre, dtype: object

# %%
print(df.dtypes)
print(df.head())
# Out:
# Release_Date          object
# Title                 object
# Overview              object
# Popularity           float64
# Vote_Count            object
# Vote_Average          object
# Original_Language     object
# Genre                 object
# Poster_Url            object
# dtype: object
#   Release_Date                    Title  \
# 0   15-12-2021  Spider-Man: No Way Home
# 1   01-03-2022               The Batman
# 2   25-02-2022                  No Exit
# 3   24-11-2021                  Encanto
# 4   22-12-2021           The King's Man
#
#                                             Overview  Popularity Vote_Count  \
# 0  Peter Parker is unmasked and no longer able to...    5083.954       8940
# 1  In his second year of fighting crime, Batman u...    3827.658       1151
# 2  Stranded at a rest stop in the mountains durin...    2618.087        122
# 3  The tale of an extraordinary family, the Madri...    2402.201       5076
# ...

# %%
df.describe(include= 'all')
# Out:
#        Release_Date                 Title  \
# count          9837                  9828
# unique         5903                  9514
# top      10-03-2022  Beauty and the Beast
# freq             16                     4
# mean            NaN                   NaN
# std             NaN                   NaN
# min             NaN                   NaN
# 25%             NaN                   NaN
# 50%             NaN                   NaN
# 75%             NaN                   NaN
# max             NaN                   NaN
#
#                                                  Overview   Popularity  \
# count                                                9828  9827.000000
# unique                                               9823          NaN
# top     Dr. Raichi is one of the only survivors of the...          NaN
# freq                                                    2          NaN
# mean                                                  NaN    40.320570
# ...

# %%
# Replace 'col1', 'col2', 'col3' with your actual column names
df['Vote_Count'] = pd.to_numeric(df['Vote_Count'], errors='coerce')
df['Vote_Average'] = pd.to_numeric(df['Vote_Average'], errors='coerce')

# %%
df.describe()
# Out:
#         Popularity    Vote_Count  Vote_Average
# count  9827.000000   9826.000000   9826.000000
# mean     40.320570   1392.943721      6.439467
# std     108.874308   2611.303856      1.129797
# min       7.100000      0.000000      0.000000
# 25%      16.127500    146.000000      5.900000
# 50%      21.191000    444.000000      6.500000
# 75%      35.174500   1376.000000      7.100000
# max    5083.954000  31077.000000     10.000000

# %% [markdown]
# Exploration Summary points
# 1-We have a dataframe consist of 9834 rows and 9 cloumns.
# 2-Our dtaset has no NANs value nor duplicate values.
# 3-Rlease_date coloumn needs to be casted in to date time and to extract only to year value.
# 4- Overwiew,Original_language and Postal_url would not be useful in data analysis , so we will drop them.
# 5- There is noticible outlier in poopularity cloumn.
# 6- Vote_Avg better be categorized for proper analysis.
# 7- Genre column has comma seprated values aand white spaces that needs to be handled and cated into category.Exploration summary

# %%
df['Release_Date'] = pd.to_datetime(df['Release_Date'], format='%d-%m-%Y', errors='coerce')
print(df['Release_Date'].dtypes)
# Out:
# datetime64[ns]

# %%
df.head()
# Out:
#   Release_Date                    Title  \
# 0   2021-12-15  Spider-Man: No Way Home
# 1   2022-03-01               The Batman
# 2   2022-02-25                  No Exit
# 3   2021-11-24                  Encanto
# 4   2021-12-22           The King's Man
#
#                                             Overview  Popularity  Vote_Count  \
# 0  Peter Parker is unmasked and no longer able to...    5083.954      8940.0
# 1  In his second year of fighting crime, Batman u...    3827.658      1151.0
# 2  Stranded at a rest stop in the mountains durin...    2618.087       122.0
# 3  The tale of an extraordinary family, the Madri...    2402.201      5076.0
# 4  As a collection of history's worst tyrants and...    1895.511      1793.0
#
#    Vote_Average Original_Language                               Genre  \
# 0           8.3                en  Action, Adventure, Science Fiction
# 1           8.1                en            Crime, Mystery, Thriller
# ...

# %%
df['Release_Date'] = df['Release_Date'].dt.year
df['Release_Date'].dtypes
# Out:
# dtype('float64')

# %%
df.head()
# Out:
#    Release_Date                    Title  \
# 0        2021.0  Spider-Man: No Way Home
# 1        2022.0               The Batman
# 2        2022.0                  No Exit
# 3        2021.0                  Encanto
# 4        2021.0           The King's Man
#
#                                             Overview  Popularity  Vote_Count  \
# 0  Peter Parker is unmasked and no longer able to...    5083.954      8940.0
# 1  In his second year of fighting crime, Batman u...    3827.658      1151.0
# 2  Stranded at a rest stop in the mountains durin...    2618.087       122.0
# 3  The tale of an extraordinary family, the Madri...    2402.201      5076.0
# 4  As a collection of history's worst tyrants and...    1895.511      1793.0
#
#    Vote_Average Original_Language                               Genre  \
# 0           8.3                en  Action, Adventure, Science Fiction
# 1           8.1                en            Crime, Mystery, Thriller
# ...

# %%
print(df['Release_Date'].isna().sum())
# Out:
# 10

# %%
missing_dates = df[df['Release_Date'].isna()]
print(missing_dates)
# Out:
#       Release_Date   Title Overview  Popularity  Vote_Count  Vote_Average  \
# 1106           NaN     NaN      NaN         NaN         NaN           NaN
# 1107           NaN     NaN      NaN         NaN         NaN           NaN
# 1108           NaN     NaN      NaN         NaN         NaN           NaN
# 1109           NaN     NaN      NaN         NaN         NaN           NaN
# 1110           NaN     NaN      NaN         NaN         NaN           NaN
# 1111           NaN     NaN      NaN         NaN         NaN           NaN
# 1112           NaN     NaN      NaN         NaN         NaN           NaN
# 1113           NaN     NaN      NaN         NaN         NaN           NaN
# 1114           NaN     NaN      NaN         NaN         NaN           NaN
# 1115           NaN  61.328       35         7.1         NaN           NaN
#
#                                       Original_Language Genre Poster_Url
# 1106                                                NaN   NaN        NaN
# ...

# %%
df.dropna(subset=['Release_Date'], inplace=True)

# %%
df['Release_Date'] = df['Release_Date'].astype('int')

# %%
df.head()
# Out:
#    Release_Date                    Title  \
# 0          2021  Spider-Man: No Way Home
# 1          2022               The Batman
# 2          2022                  No Exit
# 3          2021                  Encanto
# 4          2021           The King's Man
#
#                                             Overview  Popularity  Vote_Count  \
# 0  Peter Parker is unmasked and no longer able to...    5083.954      8940.0
# 1  In his second year of fighting crime, Batman u...    3827.658      1151.0
# 2  Stranded at a rest stop in the mountains durin...    2618.087       122.0
# 3  The tale of an extraordinary family, the Madri...    2402.201      5076.0
# 4  As a collection of history's worst tyrants and...    1895.511      1793.0
#
#    Vote_Average Original_Language                               Genre  \
# 0           8.3                en  Action, Adventure, Science Fiction
# 1           8.1                en            Crime, Mystery, Thriller
# ...

# %% [markdown]
# Dropping Columns

# %%
cols=['Overview','Original_language','Poster_Url']
df.drop(cols, axis =1, inplace = True)
df.columns

# %%
df.head()
# Out:
#    Release_Date                    Title  \
# 0          2021  Spider-Man: No Way Home
# 1          2022               The Batman
# 2          2022                  No Exit
# 3          2021                  Encanto
# 4          2021           The King's Man
#
#                                             Overview  Popularity  Vote_Count  \
# 0  Peter Parker is unmasked and no longer able to...    5083.954      8940.0
# 1  In his second year of fighting crime, Batman u...    3827.658      1151.0
# 2  Stranded at a rest stop in the mountains durin...    2618.087       122.0
# 3  The tale of an extraordinary family, the Madri...    2402.201      5076.0
# 4  As a collection of history's worst tyrants and...    1895.511      1793.0
#
#    Vote_Average Original_Language                               Genre  \
# 0           8.3                en  Action, Adventure, Science Fiction
# 1           8.1                en            Crime, Mystery, Thriller
# ...

# %%
def catigorize_col(df, col, labels):

  edges = [df[col].describe()['min'],
           df[col].describe()['25%'],
           df[col].describe()['50%'],
           df[col].describe()['75%'],
           df[col].describe()['max']]

  df[col] = pd.cut(df[col], edges, labels = labels , duplicates= 'drop' )
  return df

# %%
print(df['Vote_Average'].dtype)
# Out:
# float64

# %%
labels = ['not_popular', 'below_avg', 'average', 'popular']

catigorize_col(df, 'Vote_Average', labels)

df['Vote_Average'].unique()
# Out:
# ['popular', 'below_avg', 'average', 'not_popular', NaN]
# Categories (4, object): ['not_popular' < 'below_avg' < 'average' < 'popular']

# %% [markdown]
# we'd split genres into a list and then
# explode our dataframe to have only one
# genre per row for ezch movie

# %%
# split the strings into lists
df['Genre'] = df['Genre'].str.split(', ')
# explode the lists
df = df.explode('Genre').reset_index(drop=True)
df.head()
# Out:
#    Release_Date                    Title  \
# 0          2021  Spider-Man: No Way Home
# 1          2021  Spider-Man: No Way Home
# 2          2021  Spider-Man: No Way Home
# 3          2022               The Batman
# 4          2022               The Batman
#
#                                             Overview  Popularity  Vote_Count  \
# 0  Peter Parker is unmasked and no longer able to...    5083.954      8940.0
# 1  Peter Parker is unmasked and no longer able to...    5083.954      8940.0
# 2  Peter Parker is unmasked and no longer able to...    5083.954      8940.0
# 3  In his second year of fighting crime, Batman u...    3827.658      1151.0
# 4  In his second year of fighting crime, Batman u...    3827.658      1151.0
#
#   Vote_Average Original_Language            Genre  \
# 0      popular                en           Action
# 1      popular                en        Adventure
# 2      popular                en  Science Fiction
# ...

# %%
# casting column into category
df['Genre'] = df['Genre'].astype('category')
# confirming changes
df['Genre'].dtypes
# Out:
# CategoricalDtype(categories=['Action', 'Adventure', 'Animation', 'Comedy', 'Crime',
#                   'Documentary', 'Drama', 'Family', 'Fantasy', 'History',
#                   'Horror', 'Music', 'Mystery', 'Romance', 'Science Fiction',
#                   'TV Movie', 'Thriller', 'War', 'Western'],
# , ordered=False, categories_dtype=object)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 25793 entries, 0 to 25792
# Data columns (total 9 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   Release_Date       25793 non-null  int64
#  1   Title              25793 non-null  object
#  2   Overview           25793 non-null  object
#  3   Popularity         25792 non-null  float64
#  4   Vote_Count         25792 non-null  float64
#  5   Vote_Average       25551 non-null  category
#  6   Original_Language  25792 non-null  object
#  7   Genre              25792 non-null  category
#  8   Poster_Url         25792 non-null  object
# dtypes: category(2), float64(2), int64(1), object(4)
# memory usage: 1.4+ MB

# %%
df.nunique()
# Out:
# Release_Date          102
# Title                9513
# Overview             9822
# Popularity           8159
# Vote_Count           3266
# Vote_Average            4
# Original_Language      43
# Genre                  19
# Poster_Url           9826
# dtype: int64

# %%
df.head()
# Out:
#    Release_Date                    Title  \
# 0          2021  Spider-Man: No Way Home
# 1          2021  Spider-Man: No Way Home
# 2          2021  Spider-Man: No Way Home
# 3          2022               The Batman
# 4          2022               The Batman
#
#                                             Overview  Popularity  Vote_Count  \
# 0  Peter Parker is unmasked and no longer able to...    5083.954      8940.0
# 1  Peter Parker is unmasked and no longer able to...    5083.954      8940.0
# 2  Peter Parker is unmasked and no longer able to...    5083.954      8940.0
# 3  In his second year of fighting crime, Batman u...    3827.658      1151.0
# 4  In his second year of fighting crime, Batman u...    3827.658      1151.0
#
#   Vote_Average Original_Language            Genre  \
# 0      popular                en           Action
# 1      popular                en        Adventure
# 2      popular                en  Science Fiction
# ...

# %% [markdown]
# **Data Visualization
# here,**

# %%
# setting up seaborn configurations
sns.set_style('whitegrid')

# %% [markdown]
# Q1: What is the most frequent genre in the dataset?

# %%
df['Genre'].describe()
# Out:
# count     25792
# unique       19
# top       Drama
# freq       3744
# Name: Genre, dtype: object

# %%
# visualizing genre column
sns.catplot(y = 'Genre', data = df, kind = 'count',
order = df['Genre'].value_counts().index,
color = '#4287f5')
plt.title('genre column distribution')
plt.show()

# %% [markdown]
# Q2: What genres has highest votes ?

# %%
sns.catplot(y = 'Vote_Average', data = df, kind = 'count',
order = df['Vote_Average'].value_counts().index,
color = '#4287f5')
plt.title('votes destribution')
plt.show()

# %% [markdown]
# Q3: What movie got the highest popularity ? what's its
# genre ?

# %%
df[df['Popularity'] == df['Popularity'].max()]
# Out:
#    Release_Date                    Title  \
# 0          2021  Spider-Man: No Way Home
# 1          2021  Spider-Man: No Way Home
# 2          2021  Spider-Man: No Way Home
#
#                                             Overview  Popularity  Vote_Count  \
# 0  Peter Parker is unmasked and no longer able to...    5083.954      8940.0
# 1  Peter Parker is unmasked and no longer able to...    5083.954      8940.0
# 2  Peter Parker is unmasked and no longer able to...    5083.954      8940.0
#
#   Vote_Average Original_Language            Genre  \
# 0      popular                en           Action
# 1      popular                en        Adventure
# 2      popular                en  Science Fiction
#
#                                           Poster_Url
# 0  https://image.tmdb.org/t/p/original/1g0dhYtq4i...
# 1  https://image.tmdb.org/t/p/original/1g0dhYtq4i...
# 2  https://image.tmdb.org/t/p/original/1g0dhYtq4i...

# %% [markdown]
# Q4: What movie got the lowest popularity? what's its genre?

# %%
df[df['Popularity'] == df['Popularity'].min()]
# Out:
#        Release_Date                                 Title  \
# 25787          2021  The United States vs. Billie Holiday
# 25788          2021  The United States vs. Billie Holiday
# 25789          2021  The United States vs. Billie Holiday
# 25790          1984                               Threads
# 25791          1984                               Threads
# 25792          1984                               Threads
#
#                                                 Overview  Popularity  \
# 25787  Billie Holiday spent much of her career being ...      13.354
# 25788  Billie Holiday spent much of her career being ...      13.354
# 25789  Billie Holiday spent much of her career being ...      13.354
# 25790  Documentary style account of a nuclear holocau...      13.354
# 25791  Documentary style account of a nuclear holocau...      13.354
# 25792  Documentary style account of a nuclear holocau...      13.354
#
#        Vote_Count Vote_Average Original_Language            Genre  \
# ...

# %% [markdown]
# Q5: Which year has the most filmmed movies?

# %%
df['Release_Date'].hist()
plt.title('Release_Date column distribution')
plt.show()
